# %%
# %pip install -r requirements-estimation.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall pandas -y
# %pip install pandas --upgrade
# Out:
# Found existing installation: pandas 3.0.2
# Uninstalling pandas-3.0.2:
#   Successfully uninstalled pandas-3.0.2
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached pandas-3.0.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# ...
# Using cached pandas-3.0.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.3 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 9.2.0 requires pandas<3,>=1.5.3, but you have pandas 3.0.2 which is incompatible.
# otter-grader 6.1.3 requires wrapt<2.0.0,>=1.16.0, but you have wrapt 2.1.1 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
NG_URL= "https://docs.google.com/spreadsheets/d/1rbWPdn_Rt3MRoFb_wkomHBcNVmM-3F3lNwCpxP5W_3g/edit?gid=1354121303#gid=1354121303"

# %%
from eep153_tools.sheets import read_sheets

# %%
import pandas as pd
import numpy as np

FE_Sheets = ["Food Expenditures (2010Q3)", "Food Expenditures (2011Q1)", "Food Expenditures (2012Q3)", "Food Expenditures (2013Q1)", "Food Expenditures (2015Q3)", "Food Expenditures (2016Q1)"]

FP_Sheets = ["Food Prices (2010Q3)", "Food Prices (2011Q1)", "Food Prices (2012Q3)", "Food Prices (2013Q1)", "Food Prices (2015Q3)", "Food Prices (2016Q1)"]

def prepare_data(NG_URL, FE_Sheet, household_sheet="Household Characteristics"): 
    x = read_sheets(NG_URL, sheet = FE_Sheet)
    d = read_sheets(NG_URL ,sheet = household_sheet)

    # data cleaning to ensure key columns match exactly
    for df in [x, d]:
        df['i'] = pd.to_numeric(df['i'], errors='coerce')
        df['t'] = df['t'].astype(str).str.strip()
        df['m'] = (
            df['m']
            .astype(str)
            .str.strip()
            .str.lower()
            .str.replace(r'\s+', ' ', regex=True)
        )


    d.columns.name = 'k'
    # remove duplicate column names, keep first occurrence
    d = d.loc[:, ~d.columns.duplicated()]

    # collapse duplicate household rows
    d = d.groupby(['i','t','m'], as_index=False).first()

    # Data comes in long format; pivot to wide (one column per food)
    x = x.pivot_table(index=['i','t','m'],columns='j',values='Expenditure',
                   aggfunc='sum')
    x = x.replace(0,np.nan) # Replace zeros with missing

    # Take logs of expenditures; call this y
    y = x

    d.set_index(['i','t','m'],inplace=True)

    # NaN in demographic columns means zero people in that category
    d = d.fillna(0)

    return y, d

# %% [markdown]
# ## [B] Nutritional Adequacy of Diet
# In this section we look at the proportion of household satisfying the adult nutrition requirement in 2010Q3.

# %%
# Extracting 2016 Q1 from y and d
y, d = prepare_data(NG_URL, "Food Expenditures (2016Q1)")

# %%
d_2016Q1 = d.xs('2016Q1', level='t').drop(columns = ['Female NA', 'Male NA'])
d_2016Q1.head()
# Out:
# k                 Female 00-03  Female 04-08  Female 09-13  Female 14-18  \
# i     m
# 10001 south east             0             1             0             0
# 10002 south east             1             1             0             0
# 10003 south east             0             0             0             1
# 10004 south east             0             0             1             0
# 10005 south east             0             0             2             0
#
# k                 Female 19-30  Female 31-50  Female 51+  Male 00-03  \
# i     m
# 10001 south east             0             2           0           1
# 10002 south east             0             1           0           0
# 10003 south east             0             1           0           0
# 10004 south east             0             0           1           0
# 10005 south east             1             1           0           1
#
# k                 Male 04-08  Male 09-13  Male 14-18  Male 19-30  Male 31-50  \
# i     m
# ...

# %%
#Minimum Dietary Nutrition Requirement

RDIs = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vR84qu7yUvdzhiHnPG_7KpVSx9FgiyLrZqJ8Ft3oK-B6xT6i4xN8CNtZ2c9PRGXqxXQCNorzWdF6NnB/pub?gid=0&single=true&output=csv')
bmin = RDIs.set_index('Nutrition')
bmin.head()
# Out:
#                       Female 00-03  Female 04-08  Female 09-13  Female 14-18  \
# Nutrition
# Energy                      1000.0        1200.0        1600.0        1800.0
# Protein                       13.0          19.0          34.0          46.0
# Fiber, total dietary          14.0          16.8          22.4          25.2
# Folate, DFE                  150.0         200.0         300.0         400.0
# Calcium, Ca                  700.0        1000.0        1300.0        1300.0
#
#                       Female 19-30  Female 31-50  Female 51+  Male 00-03  \
# Nutrition
# Energy                      2000.0        1800.0      1600.0      1000.0
# Protein                       46.0          46.0        46.0        13.0
# Fiber, total dietary          28.0          25.2        22.4        14.0
# Folate, DFE                  400.0         400.0       400.0       150.0
# Calcium, Ca                 1000.0        1000.0      1200.0       700.0
#
# ...

# %%
frames = {}
for nutrient in bmin.index:
    # Multiply the whole household df by the specific row of requirements
    frames[nutrient] = d_2016Q1.multiply(bmin.loc[nutrient], axis=1)
household_rdi = pd.concat(frames, names=['Nutrient']).reorder_levels([1, 2, 0]).sort_index()

# %%
household_rdi.head()
# Out:
# k                                             Female 00-03  Female 04-08  \
# i     m          Nutrient
# 10001 south east Calcium, Ca                           0.0        1000.0
#                  Carbohydrate, by difference           0.0         130.0
#                  Energy                                0.0        1200.0
#                  Fiber, total dietary                  0.0          16.8
#                  Folate, DFE                           0.0         200.0
#
# k                                             Female 09-13  Female 14-18  \
# i     m          Nutrient
# 10001 south east Calcium, Ca                           0.0           0.0
#                  Carbohydrate, by difference           0.0           0.0
#                  Energy                                0.0           0.0
#                  Fiber, total dietary                  0.0           0.0
#                  Folate, DFE                           0.0           0.0
#
# ...

# %%
wanted_nutrients = household_rdi.index.get_level_values('Nutrient').unique().tolist()
wanted_nutrients
# Out:
# ['Calcium, Ca',
#  'Carbohydrate, by difference',
#  'Energy',
#  'Fiber, total dietary',
#  'Folate, DFE',
#  'Iron, Fe',
#  'Magnesium, Mg',
#  'Niacin',
#  'Phosphorus, P',
#  'Potassium, K',
#  'Protein',
#  'Riboflavin',
#  'Thiamin',
#  'Vitamin A, RAE',
#  'Vitamin B-12',
#  'Vitamin B-6',
#  'Vitamin C, total ascorbic acid',
#  'Vitamin E (alpha-tocopherol)',
#  'Vitamin K (phylloquinone)',
#  'Zinc, Zn']

# %%
food_nutrients = (
    pd.read_csv('FoodNutrientsNG.csv')
    .set_index('Unnamed: 0')
    .rename_axis('Nutrient')
)[wanted_nutrients]

food_nutrients.shape
# Out:
# (41, 20)

# %% [markdown]
# # Household Nutrient Intake Model
#
# We aim to compute total nutrient intake for each household and compare it with recommended intake levels.
#
# ## Definitions
#
# - $i$: household
# - $j$: nutrient (e.g., protein, calcium)
# - $k \in \mathcal{L}$: food item from the set of foods $\mathcal{L}$
#
# ## Recommended Nutrient Intake
#
# Let $r_i^j$ denote the recommended intake of nutrient $j$ for household $i$. This is computed by aggregating across all household members:
#
# $$
# r_i^j = \sum (\text{row}_i^j)
# $$
#
# where the summation is taken from the DataFrame `household_rdi`, which provides individual-level recommended daily intake values.
#
# ## Converting Expenditure to Quantity
#
# Let:
#
# - $E_i^k$: total expenditure of household $i$ on food $k$
# - $P^k$: price per kg of food $k$
#
# The quantity of food $k$ consumed, in grams, is:
#
# $$
# Q_i^k = \frac{E_i^k}{P^k} \times 1000
# $$
#
# ## Nutrient Content of Food
#
# Let $N_j^k$ denote the amount of nutrient $j$ in food $k$, measured per 100g from FoodData Central.
#
# ## Total Nutrient Intake
#
# The total intake of nutrient $j$ for household $i$, denoted $v_i^j$, is:
#
# $$
# v_i^j = \sum_{k \in \mathcal{L}} \left( \frac{E_i^k}{P^k} \times \frac{1000}{100} \times N_j^k \right)
# $$
#
# Simplifying:
#
# $$
# v_i^j = \sum_{k \in \mathcal{L}} \left( \frac{E_i^k}{P^k} \times 10 \times N_j^k \right)
# $$
#
# ## Matrix Formulation
#
# Define:
#
# - $Q_i^k = \frac{E_i^k}{P^k} \times 1000$: quantity of food $k$ consumed by household $i$, in grams
# - $A_{kj} = \frac{N_j^k}{100}$: amount of nutrient $j$ per gram of food $k$
#
# Then:
#
# $$
# v_i^j = \sum_k Q_i^k A_{kj}
# $$
#
# or in matrix form:
#
# $$
# \mathbf{V} = \mathbf{Q}\mathbf{A}
# $$
#
# ## Nutrient Adequacy
#
# We compare intake to recommended levels using:
#
# $$
# \text{Adequacy}_i^j = \frac{v_i^j}{r_i^j}
# $$
#
# - If $\text{Adequacy}_i^j > 1$, intake is sufficient.
# - If $\text{Adequacy}_i^j < 1$, intake is deficient.
#
# ## Assumptions
#
# - All purchased food is consumed, with no waste.
# - Prices accurately reflect quantities purchased.
# - Nutrient values are constant across foods and households.
# - Food categories are mapped correctly to nutrient data.

# %%
#load price data
prices =read_sheets(NG_URL, sheet = 'Food Prices (2016Q1)')
price_wide = prices.pivot(index=['t', 'm'], columns='j', values='Price')
exp_df = y

# Foods available in all three datasets
matched_foods = (
    exp_df.columns
    .intersection(food_nutrients.index)
    .intersection(price_wide.columns)
)
# Expenditure matrix
E = exp_df[matched_foods]


# Build a dataframe with the household index keys
keys = E.index.to_frame(index=False)[['i', 't', 'm']]

# %%
matched_foods
# Out:
# Index(['Bananas', 'Beef', 'Bread', 'Brown beans', 'Cassava (root)',
#        'Cassava flour', 'Chicken', 'Chocolate drinks', 'Condiments', 'Eggs',
#        'Fish--dried', 'Fish--fresh', 'Fish--frozen', 'Fish--smoked', 'Gari',
#        'Goat', 'Groundnut oil', 'Groundnuts',
#        'Leaves (Cocoyam, Spinach, etc.)', 'Maize flour', 'Malt drinks',
#        'Milk powder', 'Milk tinned (unsweetened)', 'Millet', 'Okra', 'Onions',
#        'Other vegetables (fresh or canned)', 'Palm oil', 'Pepper', 'Plantains',
#        'Rice--imported', 'Rice--local', 'Sachet water',
#        'Soft drinks (Coca Cola, spirit, etc)', 'Sugar', 'Sweet potatoes',
#        'Tea', 'Tomato puree (canned)', 'Tomatoes', 'White beans',
#        'Yam--roots'],
#       dtype='str')

# %%
# Price table: (t, m) x food
P = (
    price_wide
    .reset_index()
    .drop(columns='t')     # remove t since constant
    .set_index('m')        # now index is just region
)[matched_foods]

P.index = (
    P.index.astype(str)
    .str.strip()
    .str.lower()
)

# %%
m_index = E.index.get_level_values('m')
m_index

P_aligned = P.loc[m_index]
P_aligned.index = E.index
P_aligned = P_aligned[E.columns]

# Quantity in grams
Q = (E / P_aligned) * 1000

# Nutrient content per gram
A = food_nutrients.loc[matched_foods].fillna(0) / 100

# Total nutrient intake
v = Q.fillna(0) @ A

# %%
r = household_rdi.sum(axis=1).unstack('Nutrient')

# %%
#divide v by 91.3125 for average daily consumption
v_daily = v/91.3125
v_daily
# Out:
#                              Calcium, Ca  Carbohydrate, by difference  \
# i      t      m
# 10001  2016Q1 south east       63.165888                    68.754604
# 10002  2016Q1 south east      122.348598                    85.468253
# 10003  2016Q1 south east       79.673562                    49.758602
# 10004  2016Q1 south east       38.660922                    39.279639
# 10005  2016Q1 south east       45.876287                    52.184388
# ...                                  ...                          ...
# 370036 2016Q1 north central    59.592288                    79.861775
# 370037 2016Q1 north central    37.199835                    61.542756
# 370038 2016Q1 north central    47.221902                    87.669159
# 370039 2016Q1 north central    40.001861                    71.160428
# 370040 2016Q1 north central    35.582642                    71.146843
#
#                                   Energy  Fiber, total dietary  Folate, DFE  \
# i      t      m
# ...

# %%
adequacy = v_daily/r

# %%
adequacy
# Out:
#                              Calcium, Ca  Carbohydrate, by difference  \
# i      t      m
# 10001  2016Q1 south east        0.011082                     0.088147
# 10002  2016Q1 south east        0.024470                     0.131490
# 10003  2016Q1 south east        0.011547                     0.063793
# 10004  2016Q1 south east        0.008054                     0.075538
# 10005  2016Q1 south east        0.006036                     0.057345
# ...                                  ...                          ...
# 370036 2016Q1 north central     0.010455                     0.102387
# 370037 2016Q1 north central     0.006643                     0.094681
# 370038 2016Q1 north central     0.010982                     0.168595
# 370039 2016Q1 north central     0.004301                     0.060821
# 370040 2016Q1 north central     0.005157                     0.091214
#
#                                Energy  Fiber, total dietary  Folate, DFE  \
# i      t      m
# ...

# %% [markdown]
# To summarize nutritional outcomes at the regional level, household-level adequacy measures are aggregated by region.
#
# Let $\text{Adequacy}_{i,m}^j$ denote nutrient adequacy for household $i$ in region $m$. Regional average adequacy is computed as
#
# $$
# \text{Adequacy}_m^j = \mathbb{E}_i \left[ \text{Adequacy}_{i,m}^j \right].
# $$
#
# We also define an inadequacy gap as
#
# $$
# \text{Inadequacy}_{i,m}^j = \max(0, 1 - \text{Adequacy}_{i,m}^j),
# $$
#
# and report the regional average:
#
# $$
# \text{Inadequacy}_m^j = \mathbb{E}_i \left[ \text{Inadequacy}_{i,m}^j \right].
# $$
#
# Finally, the share of households below recommended intake is computed as
#
# $$
# \Pr(\text{Adequacy}_{i,m}^j < 1).
# $$

# %%
r_clean = r.replace(0, np.nan)
adequacy = v_daily / r_clean
regional_adequacy = adequacy.groupby(level='m').mean()
regional_adequacy
# Out:
#                Calcium, Ca  Carbohydrate, by difference    Energy  \
# m
# north central     0.015477                     0.177761  0.228545
# north east        0.010862                     0.131746  0.159364
# north west        0.009663                     0.086727  0.107444
# south east        0.018640                     0.221888  0.217823
# south south       0.015594                     0.148806  0.186022
# south west        0.015298                     0.141389  0.205759
#
#                Fiber, total dietary  Folate, DFE  Iron, Fe  Magnesium, Mg  \
# m
# north central              0.100559     0.047243  0.071828       0.058000
# north east                 0.064739     0.037761  0.068747       0.062628
# north west                 0.042824     0.035064  0.054273       0.037269
# south east                 0.090668     0.052595  0.076331       0.062733
# south south                0.064443     0.032529  0.070840       0.049539
# ...

# %%
regional_inadequacy = (1 - adequacy).clip(lower=0).groupby(level='m').mean()
regional_inadequacy
# Out:
#                Calcium, Ca  Carbohydrate, by difference    Energy  \
# m
# north central     0.984523                     0.823877  0.774461
# north east        0.989138                     0.869756  0.843151
# north west        0.990337                     0.913273  0.892556
# south east        0.981360                     0.803194  0.788296
# south south       0.984406                     0.851525  0.815523
# south west        0.984702                     0.871107  0.800135
#
#                Fiber, total dietary  Folate, DFE  Iron, Fe  Magnesium, Mg  \
# m
# north central              0.899499     0.952757  0.928172       0.942000
# north east                 0.935261     0.962239  0.931378       0.937372
# north west                 0.957176     0.964936  0.945727       0.962731
# south east                 0.911438     0.948446  0.923815       0.938666
# south south                0.935557     0.967471  0.929540       0.950461
# ...

# %% [markdown]
# # Heatmap of regional adequacy

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.heatmap(
    regional_adequacy,
    cmap='coolwarm',
    center=1,           # 1 = adequate
    annot=False,
    linewidths=0.5
)

plt.title('Regional Nutrient Adequacy (1 = Meets Requirement)')
plt.xlabel('Nutrients')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %%
import numpy as np

log_adequacy = np.log10(regional_adequacy)

plt.figure(figsize=(12, 6))

sns.heatmap(
    log_adequacy,
    cmap='coolwarm',   # great for gradients
    annot=False
)

plt.title('Log-scaled Nutrient Adequacy')
plt.show()

# %% [markdown]
# # Policy 1 Simulation: Food Subsidy Impact

# %%
foods = ["Milk powder", "Green Leaves", "Plantains", "Fish", "Rice", "Eggs"]

nutrient_map = {
    "Milk powder": ["Calcium", "Magnesium"],
    "Green Leaves": ["Vitamin A", "Folate"],
    "Plantains": ["Vitamin K"],
    "Fish": ["Vitamin K"],
    "Rice": ["Folate"],
    "Eggs": ["Riboflavin"]
}

# %%
subsidies = [0.03, 0.05, 0.08, 0.10]
elasticity = -0.8

# %% [markdown]
# multiplier=1+(−ϵ⋅subsidy)

# %%
def consumption_multiplier(subsidy, elasticity=-0.8):
    return 1 + (-elasticity * subsidy)

# %%
# baseline adequacy (example structure)
# index = nutrients, values = adequacy %
baseline = {
    "Calcium": 0.015,
    "Magnesium": 0.05,
    "Vitamin A": 0.03,
    "Folate": 0.045,
    "Vitamin K": 0.017,
    "Riboflavin": 0.045
}

# %%
import pandas as pd

results = pd.DataFrame(index=baseline.keys(), columns=subsidies)

for s in subsidies:
    mult = consumption_multiplier(s)
    
    new_vals = {}
    for nutrient in baseline:
        # assume nutrient increases proportional to relevant food
        new_vals[nutrient] = baseline[nutrient] * mult
    
    results[s] = pd.Series(new_vals)

results.columns = ["3%", "5%", "8%", "10%"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.heatmap(
    results,
    annot=True,
    fmt=".2f",
    cmap="RdYlGn",   # red → yellow → green
    center=0.5       # if normalized to adequacy = 1
)

plt.title("Nutrient Adequacy Under Food Subsidy Scenarios")
plt.xlabel("Subsidy Level")
plt.ylabel("Nutrients")

plt.show()

# %%
#%pip install -r hackingfood_requirements.txt

# %%
from example_nutrition import r as uga
from example_nutrition import rdi, fct, nutrient_demand
from example_nutrition import pbar, ceteris_paribus_price
# Out:
# Index(['Malt drinks', 'Soft drinks (Coca Cola, spirit, etc)', 'Plantains',
#        'Yam--roots', 'Milk powder', 'Chicken', 'Condiments', 'Tea',
#        'Sachet water', 'Palm oil', 'Chocolate drinks', 'Tomato puree (canned)',
#        'Fish--frozen', 'Eggs', 'Bread', 'Groundnut oil', 'Beef', 'Fish--dried',
#        'Rice--local', 'Sweet potatoes', 'Fish--smoked', 'Gari', 'Sugar',
#        'Onions', 'Groundnuts', 'White beans', 'Pepper', 'Bananas', 'Tomatoes',
#        'Other vegetables (fresh or canned)', 'Rice--imported', 'Brown beans',
#        'Okra', 'Leaves (Cocoyam, Spinach, etc.)'],
#       dtype='str', name='j')

# %%
# Map your Nigerian policy foods to their primary target nutrients
# Ensure these names match your index in 'food_nutrients' and 'r' (the demand system)
policy_targets = {
    'Milk powder': ['Calcium, Ca', 'Magnesium, Mg'],
    'Leaves (Cocoyam, Spinach, etc.)': ['Vitamin A, RAE', 'Folate, total'],
    'Plantains': ['Vitamin K (phylloquinone)'],
    'Fish--frozen': ['Vitamin K (phylloquinone)'],
    'Rice--local': ['Folate, total'],
    'Eggs': ['Riboflavin']
}

# Average household characteristics (already in your notebook)
dbar = uga.d[rdi.columns].mean()
hh_rdi = rdi.replace('',0)@dbar*7

# %%
import numpy as np

xhat = uga.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
x0 = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax = plt.subplots()

my_j = 'Rice--local'  

P = np.geomspace(.01,10,50)*pbar[my_j]

# Utility of median household, given prices
U0 = uga.indirect_utility(x0,pbar)

ax.plot([uga.demands(x0,ceteris_paribus_price(my_j,p0))[my_j] for p0 in P],P)
ax.plot([uga.demands(U0,ceteris_paribus_price(my_j,p0),type="Hicksian")[my_j] for p0 in P],P)
ax.set_ylabel('Price')
ax.set_xlabel(my_j)
ax.legend(("Marshallian","Hicksian"))

# %% [markdown]
# # Welfare

# %%
def compensating_variation(U0,p0,p1):
    x0 = uga.expenditure(U0,p0)
    x1 = uga.expenditure(U0,p1)

    return x1-x0

def revenue(U0,p0,p1,type='Marshallian'):
    """(Un)Compensated revenue from taxes changing vector of prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    
    dp = p1 - p0 # Change in prices

    c = uga.demands(U0,p1,type=type)

    dp,c = dp.align(c,join='inner')

    return dp.T@c


def deadweight_loss(U0,p0,p1):
    """
    Deadweight loss of tax/subsidy scheme creating wedge in prices from p0 to p1.

    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    cv = compensating_variation(U0,p0,p1)

    return cv - revenue(U0,p0,p1,type='Hicksian')

# %%
import matplotlib.pyplot as plt
import numpy as np
# Average household characteristics
dbar = uga.d[rdi.columns].mean()

# Minimum nutrient requirements for the average household (weekly)
hh_rdi = rdi.replace('',0)@dbar*7

def compensated_nutrient_demand(U,p):
    """Nutrient vector from Hicksian demands at utility U and prices p."""
    c = uga.demands(U,p,type='Hicksian')
    fct0,c0 = fct.align(c,axis=0,join='inner')
    return fct0.T@c0

def compensated_nutrient_adequacy_ratio(U,p):
    """NAR using Hicksian demands: holds utility fixed as prices vary."""
    return compensated_nutrient_demand(U,p)/hh_rdi

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Create a list of all pairs so we can iterate by index
all_pairs = []
for food, nutrients in policy_targets.items():
    for nut in nutrients:
        all_pairs.append((food, nut))

# 2. Set up the 4x2 grid
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
axes = axes.flatten()  # Makes it easier to loop through (0 to 7)

for i, (food, nut) in enumerate(all_pairs):
    ax1 = axes[i]
    
    # --- Calculations ---
    market_price = pbar[food]
    P = np.linspace(0.5, 1.0, 50) * market_price # Increased points for a smoother search
    
    nar_levels = [compensated_nutrient_adequacy_ratio(U0, ceteris_paribus_price(food, p))[nut] for p in P]
    baseline_nar = nar_levels[-1]
    nar_gain = [np.log10(n / baseline_nar) for n in nar_levels]
    subsidy_cost = [-revenue(U0, pbar, ceteris_paribus_price(food, p), type='Hicksian') for p in P]

    # --- Plotting ---
    ax1.plot(P, nar_gain, color='tab:blue', label='Log Gain', linewidth=2)
    ax1.axhline(0, color='black', lw=1, alpha=0.5) # The y=0 line
    

    # Formatting
    ax1.set_title(f"{food}\n({nut})", fontsize=11, fontweight='bold')
    ax1.set_xlabel('Price (Naira)')
    ax1.set_ylabel("Log Nutritional Gain", color='tab:blue')

    # Cost curve
    ax2 = ax1.twinx()
    ax2.plot(P, subsidy_cost, color='tab:orange', alpha=0.6)
    ax2.set_ylabel("Cost (Naira)", color='tab:orange')

plt.tight_layout()
plt.subplots_adjust(top=0.92, hspace=0.45)
fig.suptitle('Nutritional Subsidy Impact Analysis (8 Policy Targets)', fontsize=16)
plt.show()

# %%
for my_j, UseNutrients in policy_targets.items():
    
    # Define price range
    p_market = pbar[food]
    P = np.linspace(0.1, 2.0, 50) * p_market

    fig, (ax_nar, ax_dwl) = plt.subplots(1, 2, figsize=(10, 4))

    nar_vals = [np.log(compensated_nutrient_adequacy_ratio(U0,ceteris_paribus_price(my_j,p0))[UseNutrients]) for p0 in P]
    dwl_vals = [deadweight_loss(U0,pbar,ceteris_paribus_price(my_j,p0)) for p0 in P]


    # --- Plot NAR ---
    ax_nar.plot(P, nar_vals)
    ax_nar.axhline(0)
    ax_nar.set_xlabel(f"Price of {my_j}")
    ax_nar.set_ylabel('log NAR')
    ax_nar.legend(UseNutrients)

    # --- Plot DWL ---
    ax_dwl.plot(P, dwl_vals)
    ax_dwl.set_xlabel(f"Price of {my_j}")
    ax_dwl.set_ylabel('Deadweight Loss')

    fig.suptitle(f'{my_j}: Nutrition vs Welfare Cost')
    fig.tight_layout()

    plt.show()

# %%
all_targets
# Out:
# [('Milk powder', ['Calcium, Ca', 'Magnesium, Mg']),
#  ('Leaves (Cocoyam, Spinach, etc.)', ['Vitamin A, RAE', 'Folate, total']),
#  ('Plantains', ['Vitamin K (phylloquinone)']),
#  ('Fish--frozen', ['Vitamin K (phylloquinone)']),
#  ('Rice--local', ['Folate, total']),
#  ('Eggs', ['Riboflavin'])]
