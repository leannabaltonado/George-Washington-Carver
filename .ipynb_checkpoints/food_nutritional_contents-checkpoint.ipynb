# %% [markdown]
# ## [B]Nutritional content of different food

# %% [markdown]
# We first paste in our fdc api key and install our dependencies via requirements.txt:

# %%
apikey = "6k4anDq3cih8Tre4oqT28vAxd5dKKOAfKm53hdWx"

# %%
# %pip install -r ../requirements.txt --upgrade -q
# !pip install fooddatacentral
# !pip install pint
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '../requirements.txt'
# Note: you may need to restart the kernel to use updated packages.
# ...

# %% [markdown]
# Import the necessary packages for pulling and processing data:

# %%
import pandas as pd
import fooddatacentral as fdc

# %%
from  scipy.optimize import linprog as lp
import numpy as np
import warnings

import pandas as pd
import numpy as np
import warnings
from scipy.optimize import linprog as lp

import pandas as pd
import numpy as np
import warnings
from scipy.optimize import linprog as lp

def solve_subsistence_problem(FoodNutrients, Prices, dietmin, max_weight=None, tol=1e-6, drop_vitamins=None):
    """
    Solves Stigler's Subsistence Cost Problem using minimum requirements.
    """
    
    vitamin_map = {
        'A': 'Vitamin A, RAE',
        'E': 'Vitamin E (alpha-tocopherol)',
        'C': 'Vitamin C, total ascorbic acid'
    }

    if drop_vitamins is not None:
        if isinstance(drop_vitamins, str):
            drop_vitamins = [drop_vitamins]
            
        labels_to_drop = [vitamin_map[v.upper()] for v in drop_vitamins if v.upper() in vitamin_map]
        
        dietmin = dietmin.drop(labels=labels_to_drop, errors='ignore')

    
    try: 
        p = Prices.apply(lambda x: x.magnitude)
    except AttributeError: 
        p = Prices

    p = p.dropna()
    use = p.index.intersection(FoodNutrients.columns)
    p = p[use]

    A = FoodNutrients[p.index].fillna(0)
    A = A.loc[A.index.intersection(dietmin.index)]
    A = A.reindex(dietmin.index, axis=0)
    b = dietmin

    A = A.reindex(p.index, axis=1)
    A = A.reindex(b.index, axis=0)

    result = lp(p.values, -A.values, -b.values, method='highs')

    result.A = A
    result.b = b
    
    if result.success:
        result.diet = pd.Series(result.x, index=p.index)
    else:
        warnings.warn(result.message)
        result.diet = pd.Series(np.nan, index=p.index)

    return result

# %%
dfNG = pd.DataFrame({
    "Food": [
        "Malt drinks",
        "Soft drinks (Coca Cola, spirit, etc)",
        "Plantains",
        "Yam--roots",
        "Milk powder",
        "Chicken",
        "Condiments",
        "Tea",
        "Sachet water",
        "Palm oil",
        "Chocolate drinks",
        "Milk tinned (unsweetened)",
        "Tomato puree (canned)",
        "Fish--frozen",
        "Eggs",
        "Orange/tangerine",
        "Bread",
        "Groundnut oil",
        "Beef",
        "Goat",
        "Fish--dried",
        "Maize flour",
        "Rice--local",
        "Sweet potatoes",
        "Fish--smoked",
        "Millet",
        "Gari",
        "Sugar",
        "Maize",
        "Onions",
        "Groundnuts",
        "Fish--fresh",
        "Cassava (root)",
        "White beans",
        "Pepper",
        "Bananas",
        "Guinea corn/sorghum",
        "Cassava flour",
        "Garden eggs/egg plant",
        "Tomatoes",
        "Other vegetables (fresh or canned)",
        "Rice--imported",
        "Brown beans",
        "Okra",
        "Leaves (Cocoyam, Spinach, etc.)"
    ]
})

# %%
def get_fdc_id(food_name):
    try:
        results = fdc.search(apikey, food_name)

        if results is not None and len(results) > 0:
            return results.iloc[0]["fdcId"]   # not results[0]["fdcId"]
        else:
            return None

    except Exception as e:
        print(f"Error for {food_name}: {e}")
        return None

# %%
dfNG["FDC"] = dfNG["Food"].apply(get_fdc_id)
dfNG["FDC"] = dfNG["FDC"].astype("Int64")
dfNG.head()
# Out:
#                                    Food      FDC
# 0                           Malt drinks   174866
# 1  Soft drinks (Coca Cola, spirit, etc)  2710541
# 2                             Plantains  2709563
# 3                            Yam--roots   170071
# 4                           Milk powder  2673399

# %%
nutrient_df = fdc.nutrients(apikey, "2673399")
nutrient_df
# Out:
#                               Quantity Units
# Sodium, Na                      417.00    mg
# Fatty acids, total saturated      0.00     g
# Energy                          375.00  kcal
# Potassium, K                   1708.00    mg
# Total lipid (fat)                 0.00     g
# Fatty acids, total trans          0.00     g
# Iron, Fe                          0.00    mg
# Calcium, Ca                    1292.00    mg
# Cholesterol                       0.00    mg
# Sugars, added                     0.00     g
# Total Sugars                     45.83     g
# Vitamin D (D2 + D3)               0.00    µg
# Fiber, total dietary              4.20     g
# Carbohydrate, by difference      54.17     g
# Protein                          33.33     g

# %%
dfNG["FDC"] = dfNG["FDC"].astype("Int64")
dfNG.head()
# Out:
#                                    Food      FDC
# 0                           Malt drinks   174866
# 1  Soft drinks (Coca Cola, spirit, etc)  2710541
# 2                             Plantains  2709563
# 3                            Yam--roots   170071
# 4                           Milk powder  2673399

# %%
food_nutrient_dict = {}
failed_foods = []

for _, row in dfNG.iterrows():
    food = row["Food"]
    fdc_code = row["FDC"]

    try:
        if pd.notna(fdc_code):
            # IMPORTANT FIX: string + no decimals
            nutrient_df = fdc.nutrients(apikey, str(int(fdc_code)))

            if nutrient_df is not None and "Quantity" in nutrient_df.columns:
                food_nutrient_dict[food] = nutrient_df["Quantity"]
            else:
                failed_foods.append(food)
        else:
            failed_foods.append(food)

    except Exception as e:
        print(f"{food} failed: {e}")
        failed_foods.append(food)

# %%
FoodNutrientsNG = pd.DataFrame(food_nutrient_dict)
FoodNutrientsNG_T = FoodNutrientsNG.T

FoodNutrientsNG_T.head()
# Out:
#                                       Alanine  Alcohol, ethyl  Amino acids  \
# Malt drinks                               NaN             0.0          0.0
# Soft drinks (Coca Cola, spirit, etc)      NaN             0.0          NaN
# Plantains                                 NaN             0.0          NaN
# Yam--roots                              0.063             0.0          0.0
# Milk powder                               NaN             NaN          NaN
#
#                                       Arginine   Ash  Aspartic acid  Betaine  \
# Malt drinks                                NaN  1.90            NaN      NaN
# Soft drinks (Coca Cola, spirit, etc)       NaN   NaN            NaN      NaN
# Plantains                                  NaN   NaN            NaN      NaN
# Yam--roots                               0.127  0.82          0.155      NaN
# Milk powder                                NaN   NaN            NaN      NaN
#
# ...

# %%
FoodNutrientsNG_T.to_csv("FoodNutrientsNG.csv")

# %%
wanted_nutrients = [
    "Energy",
    "Protein",
    "Total lipid (fat)",
    "Carbohydrate, by difference",
    "Fiber, total dietary",
    "Calcium, Ca",
    "Iron, Fe",
    "Potassium, K",
    "Sodium, Na"
]

clean_sheet = FoodNutrientsNG_T[wanted_nutrients]
clean_sheet
# Out:
#                                       Energy    Protein  Total lipid (fat)  \
# Malt drinks                           1720.0   5.100000              4.760
# Soft drinks (Coca Cola, spirit, etc)    42.0   0.000000              0.250
# Plantains                              531.0   2.280000             29.600
# Yam--roots                             494.0   1.530000              0.170
# Milk powder                            375.0  33.330000              0.000
# Chicken                                188.0  24.710000              9.410
# Condiments                            1136.0  16.960000             16.220
# Tea                                     34.0   0.000000              0.000
# Sachet water                             0.0   0.000000              0.000
# Palm oil                              3699.0   0.000000            100.000
# Chocolate drinks                        49.0   0.640000              0.400
# ...
